# %% [markdown]
# # Loading the Unsplash Research dataset in Pandas dataframes
#
# This notebooks is used to load the Unsplash Research dataset in Pandas dataframes for analysis (pre-requisite to download Unsplash image dataset)

# %% [markdown]
# ## Loading libraries

# %%
import numpy as np
import pandas as pd
import glob

# %% [markdown]
# ## Loading the datasets in Pandas
#
# Make sure that you correctly point to the correct path.

# %%
path = '**/*' #/unsplash-research-dataset-lite-latest'
documents = ['photos', 'keywords', 'collections', 'conversions', 'colors']
datasets = {}

for doc in documents:
  files = glob.glob(path + doc + ".tsv*")
  print(files)
  subsets = []
  for filename in files:
    print(filename) #
    df = pd.read_csv(filename, sep='\t', header=0)
    subsets.append(df)

  datasets[doc] = pd.concat(subsets, axis=0, ignore_index=True)
# Out:
# ['unsplash-research-dataset-lite-latest/photos.tsv000']
# unsplash-research-dataset-lite-latest/photos.tsv000
# ['unsplash-research-dataset-lite-latest/keywords.tsv000']
# unsplash-research-dataset-lite-latest/keywords.tsv000
# ['unsplash-research-dataset-lite-latest/collections.tsv000']
# unsplash-research-dataset-lite-latest/collections.tsv000
# ['unsplash-research-dataset-lite-latest/conversions.tsv000']
# unsplash-research-dataset-lite-latest/conversions.tsv000
# ['unsplash-research-dataset-lite-latest/colors.tsv000']
# unsplash-research-dataset-lite-latest/colors.tsv000

# %% [markdown]
# ## Exploring the datasets (optional)
#
# Here are the first couple of rows from each dataset, as an example.

# %%
datasets['photos'].head()
# Out:
#       photo_id                                photo_url  \
# 0  bygTaBey1Xk  https://unsplash.com/photos/bygTaBey1Xk
# 1  gXSFnk2a9V4  https://unsplash.com/photos/gXSFnk2a9V4
# 2  grg6-DNJuaU  https://unsplash.com/photos/grg6-DNJuaU
# 3  sO42hhChB1c  https://unsplash.com/photos/sO42hhChB1c
# 4  tkk8_HakQ98  https://unsplash.com/photos/tkk8_HakQ98
#
#                                      photo_image_url  \
# 0  https://images.unsplash.com/uploads/1413387620...
# 1  https://images.unsplash.com/reserve/jEs6K0y1Sb...
# 2  https://images.unsplash.com/uploads/1412192004...
# 3  https://images.unsplash.com/reserve/ijl3tATFRp...
# 4  https://images.unsplash.com/reserve/6vaWXsQuSW...
#
#            photo_submitted_at photo_featured  photo_width  photo_height  \
# 0  2014-10-15 15:40:40.111061              t         4635          3070
# 1         2014-07-10 18:36:06              t         2448          3264
# 2  2014-10-01 19:33:56.393181              t         5184          3456
# 3         2014-08-19 21:15:40              t         4896          3264
# 4         2014-05-05 18:31:06              t         2000          1333
#
#    photo_aspect_ratio      photo_description photographer_username  ...  \
# 0                1.51                    NaN      jaspervandermeij  ...
# 1                0.75         Coastline view      kimberlyrichards  ...
# 2                1.50                    NaN         marcusdallcol  ...
# 3                1.50      Hazy Ocean Waters          arturpokusin  ...
# 4                1.50  Silhouettes In Desert                carlov  ...
#
#   photo_location_country photo_location_city stats_views stats_downloads  \
# 0                    NaN                 NaN     1708356           19085
# 1          United States           Tillamook     9895033           74702
# 2                    NaN                 NaN     8967968           38338
# 3                    NaN                 NaN     2071752           10860
# 4                    NaN                 NaN     2720281            9081
#
#                                      ai_description ai_primary_landmark_name  \
# 0  sea and rock cliff with grasses under cloudy sky              Neist Point
# 1                    aerial photography of seashore                      NaN
# 2     man surfboarding on ocean wave during daytime                      NaN
# 3                                     body of water                      NaN
# 4                       car on desert during sunset                      NaN
#
#   ai_primary_landmark_latitude ai_primary_landmark_longitude  \
# 0                    57.428387                     -6.783028
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#   ai_primary_landmark_confidence                     blur_hash
# 0                      30.348906  LcE{wnIVRixt~WR+NGjbxukCWBWB
# 1                            NaN  LXE4G#IARjj]GdWFxaWBDOxaofj[
# 2                            NaN  LcHx?5R%Rjof01bHWBof4ooMoeax
# 3                            NaN  LyOzVsj[aefQ_4j[ayj[IUayj[ay
# 4                            NaN  LYEV]I%19ZR+-=s,RkWW00WB%2j[
#
# [5 rows x 31 columns]

# %%
datasets['keywords'].head()
# Out:
#       photo_id   keyword  ai_service_1_confidence  ai_service_2_confidence  \
# 0  zzwTUqvzIFg      rock                15.485713                      NaN
# 1  zzwTUqvzIFg     cross                19.598213                      NaN
# 2  zzwTUqvzIFg  eruption                34.787167                      NaN
# 3  zzwTUqvzIFg    sunset                30.080654                      NaN
# 4  zzwTUqvzIFg   eclipse                39.832775                      NaN
#
#   suggested_by_user
# 0                 f
# 1                 f
# 2                 f
# 3                 f
# 4                 f

# %%
datasets['collections'].head()
# Out:
#       photo_id collection_id    collection_title          photo_collected_at
# 0  --2IBUMom1I       1230101              Travel  2017-09-27 11:24:17.575047
# 1  --2IBUMom1I       9832457            business  2020-04-04 14:26:10.506402
# 2  --2IBUMom1I       2143051     Travel / Places  2018-05-22 23:20:05.898545
# 3  --2IBUMom1I   FBJEaBSjBvg            Settings  2022-06-04 03:56:40.892078
# 4  --2IBUMom1I        162470  Majestical Sunsets  2016-03-15 17:04:25.089589

# %%
datasets['conversions'].head()
# Out:
#               converted_at conversion_type                 keyword  \
# 0  2023-05-09 11:03:40.445        download                    Mond
# 1  2023-05-09 11:12:05.109        download       16.9 camel desert
# 2  2023-05-09 11:17:33.417        download                    bird
# 3  2023-05-09 11:32:03.943        download               night sky
# 4  2023-05-09 11:36:56.557        download  zoom background office
#
#       photo_id                     anonymous_user_id conversion_country
# 0  jlV2k_Fx0fc  4589085a-75df-417b-93de-22adf2fc627d                 DE
# 1  yNGQ830uFB4  e05af0fe-4930-421d-b20d-f904f316e2c3                 CN
# 2  BFsm5vldl2I  64fd6739-db67-46e0-99f2-022efb498447                 RU
# 3  -cKXtsJWU-I  2f9c6ac4-02c8-4d0f-82b3-0482a82ab0bf                 IN
# 4  CEeoDFpVxxw  a7abbff5-4a50-4c65-b463-18139e2978e9                 IN

# %%
datasets['colors'].head()
# Out:
#       photo_id     hex  red  green  blue         keyword  ai_coverage  \
# 0  XDPk8ndzNho  5B534C   91     83    76  darkolivegreen     0.065067
# 1  IfL3QovlAbI  371511   55     21    17           black     0.105533
# 2  GKzgF32piaE  8ACCD5  138    204   213         skyblue     0.044867
# 3  T5WR9adosj8  A59A99  165    154   153        darkgray     0.050800
# 4  T5WR9adosj8  7F7575  127    117   117            gray     0.050533
#
#    ai_score
# 0  0.030752
# 1  0.203291
# 2  0.128655
# 3  0.048626
# 4  0.030054

# %% [markdown]
# Analyze data where we have latitude information

# %%
df = datasets['photos']
df[~df['ai_primary_landmark_latitude'].isna()]
# Out:
#           photo_id                                photo_url  \
# 0      bygTaBey1Xk  https://unsplash.com/photos/bygTaBey1Xk
# 44     WuAKYGlcgmA  https://unsplash.com/photos/WuAKYGlcgmA
# 89     oGBhhnsIk6c  https://unsplash.com/photos/oGBhhnsIk6c
# 104    vg9_eeLjnzw  https://unsplash.com/photos/vg9_eeLjnzw
# 110    xRsPg9Z8Ls0  https://unsplash.com/photos/xRsPg9Z8Ls0
# ...            ...                                      ...
# 24769  7wk0ja-DP_c  https://unsplash.com/photos/7wk0ja-DP_c
# 24818  ptp1UHJ6c5M  https://unsplash.com/photos/ptp1UHJ6c5M
# 24899  S-5qu7iwQfc  https://unsplash.com/photos/S-5qu7iwQfc
# 24900  -6hvB84fyYA  https://unsplash.com/photos/-6hvB84fyYA
# 24913  xpVh9nbRcWw  https://unsplash.com/photos/xpVh9nbRcWw
#
#                                          photo_image_url  \
# 0      https://images.unsplash.com/uploads/1413387620...
# 44     https://images.unsplash.com/photo-1543487546-5...
# 89     https://images.unsplash.com/photo-156781392398...
# 104    https://images.unsplash.com/photo-157859641741...
# 110    https://images.unsplash.com/photo-158052169873...
# ...                                                  ...
# 24769  https://images.unsplash.com/photo-147604102652...
# 24818  https://images.unsplash.com/photo-151733923966...
# 24899  https://images.unsplash.com/photo-157367666051...
# 24900  https://images.unsplash.com/photo-157640551554...
# 24913  https://images.unsplash.com/photo-156366317013...
#
#                photo_submitted_at photo_featured  photo_width  photo_height  \
# 0      2014-10-15 15:40:40.111061              t         4635          3070
# 44     2018-11-29 10:33:27.297023              t         6000          4000
# 89     2019-09-07 00:09:00.964888              t         3628          4535
# 104    2020-01-09 19:00:32.132759              t         5168          3445
# 110    2020-02-01 01:49:46.811042              t         2765          3456
# ...                           ...            ...          ...           ...
# 24769   2016-10-09 19:24:37.20838              t         3024          3780
# 24818  2018-01-30 19:09:21.081108              t         2000          3008
# 24899  2019-11-13 20:24:50.319771              t         3886          5829
# 24900  2019-12-15 10:27:00.313398              t         4000          6000
# 24913  2019-07-20 22:53:29.669679              t         2872          3588
#
#        photo_aspect_ratio                                  photo_description  \
# 0                    1.51                                                NaN
# 44                   1.50                                                NaN
# 89                   0.80  #montenegro #travel #outdoors #adventures #fol...
# 104                  1.50                                                NaN
# 110                  0.80                       The mighty Gorges Du Verdon.
# ...                   ...                                                ...
# 24769                0.80                                                NaN
# 24818                0.66                                 Gone with the wind
# 24899                0.67  Early cold morning at Lake Louise.  Instagram ...
# 24900                0.67                   THE OLD MAN - Scotland Landscape
# 24913                0.80                            Multnomah Falls, Oregon
#
#       photographer_username  ... photo_location_country photo_location_city  \
# 0          jaspervandermeij  ...                    NaN                 NaN
# 44              martinpechy  ...                    NaN                 NaN
# 89                 todorraw  ...                    NaN                 NaN
# 104           alex_akimenko  ...                 Италия            Манарола
# 110        william_sinclair  ...                 France                 NaN
# ...                     ...  ...                    ...                 ...
# 24769           lifeasyoshi  ...          United States                 NaN
# 24818          bertrand1212  ...          United States                 NaN
# 24899                touann  ...                    NaN                 NaN
# 24900          therawhunter  ...            Regno Unito                 NaN
# 24913                 meric  ...          United States       Cascade Locks
#
#       stats_views stats_downloads  \
# 0         1708356           19085
# 44        7136266            6576
# 89         322072            1700
# 104        716780            2127
# 110        519254            2052
# ...           ...             ...
# 24769     8473740           97827
# 24818      710531            4272
# 24899     1426487           12267
# 24900     5505807          148112
# 24913     1832129           33333
#
#                                           ai_description  \
# 0       sea and rock cliff with grasses under cloudy sky
# 44                         green grass mountain near sea
# 89                           green leafed plants on hill
# 104    aerial photography of city with high-rise buil...
# 110             river between green trees during daytime
# ...                                                  ...
# 24769                                 lake water scenery
# 24818                           antelope Canyon, Arizona
# 24899                                white snow mountain
# 24900  a group of rocks sitting on top of a lush gree...
# 24913                                   waterfalls photo
#
#                     ai_primary_landmark_name ai_primary_landmark_latitude  \
# 0                                Neist Point                    57.428387
# 44                             Man O'War Bay                    50.621846
# 89     Mausoleum of Petar II Petrovic-Njegos                    42.399899
# 104       Parco Nazionale delle Cinque Terre                    44.128109
# 110                             Verdon Gorge                    43.767623
# ...                                      ...                          ...
# 24769                            Blanca Lake                    47.936241
# 24818                        Antelope Canyon                    36.865956
# 24899                    Banff National Park                    51.496846
# 24900                       Old Man of Storr                    57.506323
# 24913                        Multnomah Falls                    45.577450
#
#       ai_primary_landmark_longitude ai_primary_landmark_confidence  \
# 0                         -6.783028                      30.348906
# 44                        -2.274685                       0.455769
# 89                        18.837534                       0.232970
# 104                        9.712391                       0.726395
# 110                        6.345978                       0.294208
# ...                             ...                            ...
# 24769                   -121.342106                      41.991177
# 24818                   -111.377850                      75.364596
# 24899                   -115.928056                       0.844728
# 24900                     -6.176891                       0.708316
# 24913                   -122.117262                       0.360513
#
#                           blur_hash
# 0      LcE{wnIVRixt~WR+NGjbxukCWBWB
# 44     LnOg1w_4M{ad_4IUofkDt7RikDf6
# 89     L~J7~@ozaxj@~qkDf6j@-;bIjZfR
# 104    LCB34$~80z585ARj-U%159EMs-%1
# 110    LLEC%l9s4TMx55sS-pX9RQ%2Nat6
# ...                             ...
# 24769  LjG9BPD%9Fj]_NIUIUay-pM{ofWB
# 24818  LCB2S|=xWBWB-A=xo0NH0zR*S2Na
# 24899  LNFZsfxa4TWX?b%Mf+WBE2tR.8oz
# 24900  LRBDB9EL$+S2WGRjWVae0c-VNGs.
# 24913  LHBgI?kW8_WB~To#S2Rj?FjJRjR*
#
# [1232 rows x 31 columns]
